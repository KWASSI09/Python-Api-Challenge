# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Get Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
weather_url = f"{url}appid={weather_api_key}&units={units}&q="

response = requests.get(weather_url + city)
city_weather_json = response.json()
print(json.dumps(city_weather_json, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -122.4286,
#         "lat": 37.4636
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 69.21,
#         "feels_like": 69.3,
#         "temp_min": 57.13,
#         "temp_max": 85.91,
#         "pressure": 1019,
#         "humidity": 74
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 16.11,
#         "deg": 320
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1657306436,
#     "sys": {
#         "type": 1,
#         "id": 4322,
#         "country": "US",
#         "sunrise": 1657284961,
#         "sunset": 1657337592
#     },
#     "timezone": -25200,
#     "id": 5354943,
#     "name": "Half Moon Bay",
#     "cod": 200
# }

# %%
#url for weather api call

url = f"http://api.openweathermap.org/data/2.5/weather?units=imperial&appid={weather_api_key}"


#Empty list of city to append data related to each city
city_data = []

print("Beginning Data Retrieval")
print ("---------------------------")

record_counter = 1
set_counter = 1
#loop through each city in the list
for index, city in enumerate(cities):
    if(index % 50 == 0 and index >= 50):
        set_counter += 1
        record_counter = 0
    #creating each city endpoint URL
    city_weath_url = url + "&q=" + city 
    
    print(f"processing record {record_counter} of set {set_counter} | {city}")
    
    record_counter +=1
    
    #exception handling
    try:
        #api request for each city
        #retrieve dat with json
        city_data_json = requests.get(city_weath_url).json()
        
        latitude = city_data_json["coord"]["lat"]
        longitude = city_data_json["coord"]["lon"]
        max_temp = city_data_json["main"]["temp_max"]
        humidity = city_data_json["main"]["humidity"]
        cloudiness = city_data_json["clouds"]["all"]
        wind_speed = city_data_json["wind"]["speed"]
        country = city_data_json["sys"]["country"]
        date = city_data_json["dt"]

        #appending data related to each city
        city_data.append({
                 "City" : city,
                 "Lat" : latitude,
                 "Lng" : longitude,
                 "Max Temp" : max_temp,
                 "Humidity" : humidity,
                 "Cloudiness" :cloudiness,
                 "Wind speed" :wind_speed,
                 "Country" :country,
                 "Date" :date        
                 })
        
    except:
        print("city not found. skipping...")
        
        print ("---------------------------")
        print("Data Retrieval Complete")
        print ("---------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# processing record 1 of set 1 | tecpan
# processing record 2 of set 1 | ilinskiy
# processing record 3 of set 1 | hermanus
# processing record 4 of set 1 | almaznyy
# processing record 5 of set 1 | maniitsoq
# processing record 6 of set 1 | rikitea
# processing record 7 of set 1 | tabialan
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 8 of set 1 | punta arenas
# processing record 9 of set 1 | havelock
# processing record 10 of set 1 | kaili
# processing record 11 of set 1 | vaini
# processing record 12 of set 1 | nebug
# processing record 13 of set 1 | kavaratti
# processing record 14 of set 1 | puerto ayora
# processing record 15 of set 1 | kracheh
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 16 of set 1 | barrow
# processing record 17 of set 1 | jarjis
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 18 of set 1 | hithadhoo
# processing record 19 of set 1 | khonuu
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 2 of set 10 | caravelas
# processing record 3 of set 10 | faya
# processing record 4 of set 10 | rawson
# processing record 5 of set 10 | hamilton
# processing record 6 of set 10 | boueni
# processing record 7 of set 10 | gat
# processing record 8 of set 10 | zhangjiakou
# processing record 9 of set 10 | mastic beach
# processing record 10 of set 10 | turukhansk
# processing record 11 of set 10 | harrison
# processing record 12 of set 10 | nastola
# processing record 13 of set 10 | mahanoro
# processing record 14 of set 10 | mogadishu
# processing record 15 of set 10 | nizwa
# processing record 16 of set 10 | tiznit
# processing record 17 of set 10 | kyren
# processing record 18 of set 10 | conde
# processing record 19 of set 10 | vao
# processing record 20 of set 10 | broome
# processing record 21 of set 10 | vilhena
# processing record 22 of set 10 | preobrazheniye
# processing record 23 of set 10 | vostok
# processing record 24 of set 10 | richards bay
# processing record 25 of set 10 | chake chake
# processing record 26 of set 10 | kushmurun
# processing record 27 of set 10 | marawi
# processing record 28 of set 10 | thai nguyen
# processing record 29 of set 10 | chicama
# processing record 30 of set 10 | asosa
# processing record 31 of set 10 | mackay
# processing record 32 of set 10 | vanavara
# processing record 33 of set 10 | la union
# processing record 34 of set 10 | havre-saint-pierre
# processing record 35 of set 10 | lamar
# processing record 36 of set 10 | changping
# processing record 37 of set 10 | afrikanda
# processing record 38 of set 10 | tutoia
# processing record 39 of set 10 | coronel mariduena
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 40 of set 10 | marsabit
# processing record 41 of set 10 | bridgton
# processing record 42 of set 10 | tomelloso
# processing record 43 of set 10 | ponta pora
# processing record 44 of set 10 | calama
# processing record 45 of set 10 | tara
# processing record 46 of set 10 | hihifo
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 47 of set 10 | san jeronimo
# processing record 48 of set 10 | ouro fino
# processing record 49 of set 10 | nago
# processing record 0 of set 11 | ndago
# processing record 1 of set 11 | mayenne
# processing record 2 of set 11 | cervo
# processing record 3 of set 11 | sarankhola
# processing record 4 of set 11 | floriano
# processing record 5 of set 11 | teguldet
# processing record 6 of set 11 | vestmanna
# processing record 7 of set 11 | kaka
# processing record 8 of set 11 | lawton
# processing record 9 of set 11 | arecibo
# processing record 10 of set 11 | aqtobe
# processing record 11 of set 11 | peniche
# processing record 12 of set 11 | sicamous
# processing record 13 of set 11 | knysna
# processing record 14 of set 11 | mangochi
# processing record 15 of set 11 | huarmey
# processing record 16 of set 11 | port blair
# processing record 17 of set 11 | acari
# processing record 18 of set 11 | khash
# processing record 19 of set 11 | ahipara
# processing record 20 of set 11 | manyana
# processing record 21 of set 11 | punta alta
# processing record 22 of set 11 | whitehaven
# processing record 23 of set 11 | saint george
# processing record 24 of set 11 | kudahuvadhoo
# processing record 25 of set 11 | oranjestad
# processing record 26 of set 11 | coolum beach
# processing record 27 of set 11 | mae hong son
# processing record 28 of set 11 | pozo colorado
# processing record 29 of set 11 | fairbanks
# processing record 30 of set 11 | tessalit
# processing record 31 of set 11 | sorland
# processing record 32 of set 11 | kanye
# processing record 33 of set 11 | port hedland
# processing record 34 of set 11 | manitouwadge
# processing record 35 of set 11 | xai-xai
# processing record 36 of set 11 | revda
# processing record 37 of set 11 | dongsheng
# processing record 38 of set 11 | san cristobal
# processing record 39 of set 11 | granja
# processing record 40 of set 11 | zelenogorskiy
# processing record 41 of set 11 | kismayo
# processing record 42 of set 11 | sao filipe
# processing record 43 of set 11 | alugan
# processing record 44 of set 11 | comodoro rivadavia
# processing record 45 of set 11 | yokadouma
# processing record 46 of set 11 | chenzhou
# processing record 47 of set 11 | awbari
# processing record 48 of set 11 | pasni
# processing record 49 of set 11 | sept-iles
# processing record 0 of set 12 | nizhneyansk
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 1 of set 12 | mirandela
# processing record 2 of set 12 | impfondo
# processing record 3 of set 12 | orange
# processing record 4 of set 12 | druzhnaya gorka
# processing record 5 of set 12 | pleasant point
# processing record 6 of set 12 | merauke
# processing record 7 of set 12 | wajima
# processing record 8 of set 12 | ambulu
# processing record 9 of set 12 | asayita
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 10 of set 12 | taseyevo
# processing record 11 of set 12 | linxia
# processing record 12 of set 12 | villaviciosa
# processing record 13 of set 12 | aklavik
# processing record 14 of set 12 | jati
# processing record 15 of set 12 | holesov
# processing record 16 of set 12 | katsuura
# processing record 17 of set 12 | shingu
# processing record 18 of set 12 | batagay-alyta
# processing record 19 of set 12 | mpongwe
# processing record 20 of set 12 | nhulunbuy
# processing record 21 of set 12 | caluire-et-cuire
# processing record 22 of set 12 | yagunovskiy
# processing record 23 of set 12 | luderitz
# processing record 24 of set 12 | zhigansk
# processing record 25 of set 12 | tabiauea
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 26 of set 12 | mkushi
# processing record 27 of set 12 | olinda
# processing record 28 of set 12 | yining
# processing record 29 of set 12 | grindavik
# processing record 30 of set 12 | misratah
# processing record 31 of set 12 | trinidad
# processing record 32 of set 12 | manica
# processing record 33 of set 12 | lander
# processing record 34 of set 12 | ostroda
# processing record 35 of set 12 | eyl
# processing record 36 of set 12 | kidal
# processing record 37 of set 12 | gioia del colle
# processing record 38 of set 12 | srivardhan
# processing record 39 of set 12 | maneadero
# processing record 40 of set 12 | gambo
# processing record 41 of set 12 | sungaipenuh
# processing record 42 of set 12 | poya
# processing record 43 of set 12 | nyakahanga
# processing record 44 of set 12 | pingliang
# processing record 45 of set 12 | rocky mountain house
# processing record 46 of set 12 | ikom
# processing record 47 of set 12 | wronki
# processing record 48 of set 12 | rancho palos verdes
# processing record 49 of set 12 | bousso
# processing record 0 of set 13 | babanusah
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 1 of set 13 | husavik
# processing record 2 of set 13 | korla
# processing record 3 of set 13 | ponta delgada
# processing record 4 of set 13 | hovd
# processing record 5 of set 13 | bolshaya murta
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 6 of set 13 | hachinohe
# processing record 7 of set 13 | terrace
# processing record 8 of set 13 | ust-kuyga
# processing record 9 of set 13 | ruatoria
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 10 of set 13 | koumac
# processing record 11 of set 13 | general roca
# processing record 12 of set 13 | kjollefjord
# processing record 13 of set 13 | peabiru
# processing record 14 of set 13 | dengzhou
# processing record 15 of set 13 | wolmaranstad
# city not found. skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------
# processing record 16 of set 13 | verkhniy avzyan
# processing record 17 of set 13 | lompoc
# processing record 18 of set 13 | cockburn town
# processing record 19 of set 13 | nang rong
# processing record 20 of set 13 | nsanje
# processing record 21 of set 13 | shamkhal
# processing record 22 of set 13 | punto fijo
# processing record 23 of set 13 | beringovskiy
# processing record 24 of set 13 | mecca
# processing record 25 of set 13 | nanlong
# processing record 26 of set 13 | micomeseng
# processing record 27 of set 13 | soanierana ivongo
# processing record 28 of set 13 | ostrovnoy
# processing record 29 of set 13 | kenai
# processing record 30 of set 13 | half moon bay

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
City_Data_df = pd.DataFrame(city_data)
City_Data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind speed  \
# 0     tecpan  14.7623 -90.9947     62.89        55           4        6.60
# 1   ilinskiy  55.6190  38.1182     64.31        82           0        0.00
# 2   hermanus -34.4187  19.2345     54.81        67           0        7.52
# 3   almaznyy  48.0448  40.0450     69.91        30          11        8.01
# 4  maniitsoq  65.4167 -52.9000     42.51        89          50       15.35
#
#   Country        Date
# 0      GT  1657314819
# 1      RU  1657314662
# 2      ZA  1657314820
# 3      RU  1657314820
# 4      GL  1657314820

# %%
#displaying basic statistical details
City_Data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind speed  \
# count  578.000000  578.000000  578.000000  578.000000  578.000000   578.00000
# mean    20.488694   17.658247   69.267093   70.145329   53.346021     8.59699
# std     33.121601   88.315306   14.098877   22.165745   40.990272     5.90600
# min    -54.800000 -175.200000   29.750000    1.000000    0.000000     0.00000
# 25%     -6.819250  -59.336825   58.740000   61.000000    7.250000     4.00000
# 50%     24.674850   22.684600   71.015000   76.000000   57.000000     7.18000
# 75%     49.714025   92.121775   79.097500   87.000000   99.000000    11.84000
# max     78.218600  179.316700  110.070000  100.000000  100.000000    34.87000
#
#                Date
# count  5.780000e+02
# mean   1.657315e+09
# std    7.470345e+01
# min    1.657314e+09
# 25%    1.657315e+09
# 50%    1.657315e+09
# 75%    1.657315e+09
# max    1.657315e+09

# %%
# exporting the city data into a .csv.
City_Data_df.to_csv("output_data/City_Data.csv", index_label = "city_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Building Scatter Plot 
plt.scatter(City_Data_df["Lat"], City_Data_df["Max Temp"],facecolors="red",alpha=0.8,linewidth=1, marker="o", edgecolor="black")
plt.title("Latitude vs. Max Temperature (09/07/2022)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save plot
plt.savefig("output_data/Latitude vs. Max_Temperature.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Building Scatter Plot 
plt.scatter(City_Data_df["Lat"], City_Data_df["Humidity"],facecolors="red",alpha=0.8,linewidth=1, marker="o", edgecolor="black")
plt.title("Latitude vs. Humidity (09/07/2022)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save plot
plt.savefig("output_data/Latitude vs. Humidity.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Building Scatter Plot 
plt.scatter(City_Data_df["Lat"], City_Data_df["Cloudiness"],facecolors="red",alpha=0.8,linewidth=1, marker="o", edgecolor="black")
plt.title("Latitude vs. Cloudiness (09/07/2022)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save plot
plt.savefig("output_data/Latitude vs. Cloudiness.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Building Scatter Plot 
plt.scatter(City_Data_df["Lat"], City_Data_df["Wind speed"],facecolors="red",alpha=0.8,linewidth=1, marker="o", edgecolor="black")
plt.title("Latitude vs. Wind speed (09/07/2022)")
plt.ylabel("Wind speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save plot
plt.savefig("output_data/Latitude vs. Wind speed.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
